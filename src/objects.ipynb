# %% [markdown]
# tworzenie klasy w pythonie

# %%
class SmartPhone:
    name = ''
    address_book={}
    def __init__(self): #self służy do odwołania się do klasy Smartphpne 
        #konstruktor jest wywoływany w momencie tworzenia obiektu klasy SmartPhone
        print('Creating a new SmartPhone object')

# %%
sp = SmartPhone() # tworzy obiekt klasy SmartPhone
# Out:
# Creating a new SmartPhone object

# %%
#class SmartPhone:
   # pass #to na razie nic nie robi, ale pozwala nam stworzyć obiekt tej klasy

# %%
type(sp), isinstance(sp, SmartPhone) # sprawdza typ obiektu sp oraz czy jest on instancją klasy SmartPhone
# Out:
# (__main__.SmartPhone, True)

# %% [markdown]
# ---

# %%
class SmartPhone:
    def __init__(self): 
        print('Creating a SmartPhone')
        self.name=name #nazwa tego self konkretnego przemdiotu to teraz name
        self.address_book={}

# %%
class SmartPhone:
    def __init__(self, name = ''): # konstruktor i jego parametry; mogę zrobić domyslny, stawiając cudzysłów
        print('Creating a SmartPhone object')
        self.name = name
        self.address_book = {}

# %%
spB = SmartPhone("Bob's phone") # tworze nowy obiekt, ktory jest instancja klasy 
spB.address_book['Alice'] = '123-456-7890'
spB.address_book['Charlie'] = '987-654-3210'

spA = SmartPhone("Alice's phone")#  `tworze nowy obiekt, ktory jest instancja klasy`
spA.address_book['Bob'] = '555-555-5555'
spA.address_book['Charlie'] = '444-444-4444'
# Out:
# Creating a SmartPhone object
# Creating a SmartPhone object

# %%
spA.name, spB.name
# Out:
# ("Alice's phone", "Bob's phone")

# %%
spA.hakuna_matata = 'It means no worries'
spA.hakuna_matata # dodaję nową właściwość do obiektu spA, która nie jest zdefiniowana w klasie SmartPhone
# Out:
# 'It means no worries'

# %%
import random

# dodajmy metodę
class SmartPhone:
    def __init__(self, name = ''):
        print('Creating a SmartPhone')
        self.name = name
        self.address_book = {}
        #losujemy kod, który będzie tajny dla każdego telefonu
        self._secret_code = random.randint(1000, 9999) # losowy kod, który będzie tajny dla każdego telefonu
        # jezeli atrybut jest z _ , to sygnał nie ruszac tego, bo jest on prywatny i nie powinien być modyfikowany z zewnątrz klasy
        
    def restart(self): # metoda restart, która będzie dostępna dla każdego obiektu klasy SmartPhone
        #zwykła funckja telefonu zwasze musi mieć w nawiasie self, bo to jest sposób, w jaki metoda wie, do którego obiektu się odnosi
        print(f'Restarting {self.name}')
        
    def send_data_to_china(self):
        print(f'Sending data from {self._secret_code} to China')

# %%
spB = SmartPhone("Bob's phone") # Tworzymy NAJPIERW instancję (obiekt)
spB.send_data_to_china()# wysyła dane do Chin, używając tajnego kodu telefonu spB
# Out:
# Creating a SmartPhone
# Sending data from 8048 to China

# %%
import random

# dodajmy metodę
class SmartPhone:
    def __init__(self, name = ''):
        print('Creating a SmartPhone')
        self.name = name
        self.address_book = {}
        self._secret_code = random.randint(1000, 9999) # losowy kod, który będzie tajny dla każdego telefonu
        # jezeli atrybut jest z podloga, to nie ruszac tego atrybutu, bo jest on prywatny i nie powinien być modyfikowany z zewnątrz klasy
        
    def restart(self): # musi przyjac argument self jako pierwszy argument
        print(f'Restarting {self.name}')
        
    def send_data_to_china(self):
        print(f'Sending data from {self._secret_code} to China')
        
    def __str__(self):# metoda, która zwraca ładną reprezentację obiektu, gdy wywołamy print na obiekcie klasy SmartPhone
        return f'SmartPhone(name={self.name}, address_book={self.address_book})' # zwraca nazwe telefonu i jego książkę adresową, gdy wywołamy print na obiekcie klasy SmartPhone
    
    def __getitem__(self, key): # wywoluje sie, gdy próbujemy uzyskać dostęp do elementu za pomocą indeksu, np. spA['Bob']
        return self.address_book[key]
    
    def __setitem__(self, key, value): # wywołuje się, gdy próbujemy ustawić wartość elementu za pomocą indeksu, np. spA['Bob'] = '555-555-5555'
        self.address_book[key] = value
        
    def __len__(self): # zwraca liczbe wpisów w książce adresowej, gdy wywołamy len(spA)
        return len(self.address_book)

# %%
spB = SmartPhone("Bob's phone") # tworze nowy obiekt, ktory jest instancja klasy 
spB.address_book['Alice'] = '123-456-7890'
spB.address_book['Charlie'] = '987-654-3210'
# Out:
# Creating a SmartPhone

# %%
spB.restart()
# Out:
# Restarting Bob's phone

# %%
spB._secret_code = 'FU'# próba zmiany tajnego kodu telefonu spB, ale to jest zły pomysł, bo ten kod jest prywatny i nie powinien być modyfikowany z zewnątrz klasy

# %%
spB.send_data_to_china()
# Out:
# Sending data from FU to China

# %%
spB = SmartPhone("Bob's phone")
spB.address_book['Alice'] = '123-456-7890'
spB.address_book['Charlie'] = '987-654-3210'
# Out:
# Creating a SmartPhone

# %%
print(spB)
# Out:
# SmartPhone(name=Bob's phone, address_book={'Alice': '123-456-7890', 'Charlie': '987-654-3210'})

# %%
spB['Alice'] # wywołuje metodę __getitem__, która zwraca numer telefonu Alice z książki adresowej spB
# Out:
# '123-456-7890'

# %%
spB['Bob'] = 'ArithmeticError'# wywołuje metodę __setitem__, która ustawia numer telefonu Bob na 'ArithmeticError' w książce adresowej spB
spB['Bob']# wywołuje metodę __getitem__, która zwraca numer telefonu Bob z książki adresowej spB, czyli 'ArithmeticError'
# Out:
# 'ArithmeticError'

# %% [markdown]
# #DZIEDZICZENIE

# %%
class ElectronicDevice:
    def __init__(self,name=''): #konstruktor, uruchamai się automatycznie gdy tworzymy nowy telefon, domyślny pusta nazwa teelfonu ''
        print('creating device')
        self.name=name
    def restart(self):
        print(f'restarting{self.name}')

class Computer(ElectronicDevice): #dziedziczenie, czyli klasa Computer dziedziczy po klasie ElectronicDevice
    pass

# %% [markdown]
# class Computer(ElectronicDevice): – Mówisz Pythonowi: „Komputer to rodzaj urządzenia elektronicznego, ma mieć wszystko to samo, co ono”.
#
#     pass – Oznacza: „nie dodaję nic nowego do komputera, użyj dokładnie tego, co jest w przepisie na urządzenie”.
#
#     Dziedziczenie konstruktora: Ponieważ Computer nie ma własnego __init__, Python idzie „piętro wyżej” do ElectronicDevice i tam szuka instrukcji. Jeśli tam znajdzie poprawnie zapisane __init__, to go użyje.

# %%
mypc = Computer('My PC') # wywołuje się konstruktor klasy bazowej
# Out:
# creating device

# %%
mypc.restart()# wywołuje metodę restart, która jest dziedziczona z klasy ElectronicDevice, więc mypc może korzystać z tej metody, mimo że jest obiektem klasy Computer
# Out:
# restartingMy PC

# %% [markdown]
# uruchamia funkcję (metodę), która została zdefiniowana w klasie nadrzędne
# Szukanie metody: Python zagląda do obiektu mypc i pyta: „Czy masz funkcję restart?”.
#
# Mechanizm dziedziczenia: Ponieważ Computer dziedziczy po ElectronicDevice, Python sprawdza przepis klasy bazowej i tam znajduje definicję tej metody.
#
# Wykonanie kodu: Odpala się linijka print(f'restarting {self.name}').
#
# Użycie danych obiektu: self.name zostanie zastąpione nazwą, którą podałeś przy tworzeniu komputera (czyli 'My PC').

# %% [markdown]
# ### MRO - Method Resolution Order - Kolejność Rozwiązywania Metod

# %% [markdown]
# Kiedy wywołujesz mypc.restart(), Python nie szuka na oślep. Idzie ścieżką MRO:
#
#     Klasa obiektu: Najpierw sprawdza, czy restart jest w klasie Computer.
#
#     Klasa nadrzędna: Jeśli nie ma go w Computer, idzie do ElectronicDevice.
#
#     Klasa object: Na samym końcu zawsze sprawdza wbudowaną klasę object (to „pradziadek” wszystkich klas w Pythonie).

# %%
#MRO metod resolution order
Computer.mro()
# Out:
# [__main__.Computer, __main__.ElectronicDevice, object]

# %%
Computer.__mro__ # pokazuje hierarchię dziedziczenia, czyli kolejność klas, 
# które są przeszukiwane podczas wywoływania metod na obiekcie klasy Computer
# Out:
# (__main__.Computer, __main__.ElectronicDevice, object)

# %%
class ElectronicDevice:
    def __init__(self, name = ''):
        print('Creating an Electronic Device')
        self.name = name
        
    def restart(self):
        print(f'Restarting {self.name}')
        
class Computer(ElectronicDevice): # dziedziczenie 
    def __init__(self, ram):
        print('Creating a Computer')
        self.ram = ram

# %%
mypc= Computer(64)
# Out:
# Creating a Computer

# %%
mypc.ram
# Out:
# 64

# %%
mypc.restart()
# pokaze sie blad - nie zostal wywolany konstruktor klasy nadrzednej
# bo dodajemy konstruktor do klasy Computer, to konstruktor klasy ElectronicDevice nie jest już wywoływany automatycznie,
# więc atrybut name nie jest ustawiony, a metoda restart próbuje uzyskać dostęp do self.name, co powoduje błąd AttributeError, 
# ponieważ self.name nie istnieje w obiekcie mypc.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 mypc.restart()
#       2 # pokaze sie blad - nie zostal wywolany konstruktor klasy nadrzednej
#       3 # bo dodajemy konstruktor do klasy Computer, to konstruktor klasy ElectronicDevice nie jest już wywoływany automatycznie,
#       4 # więc atrybut name nie jest ustawiony, a metoda restart próbuje uzyskać dostęp do self.name, co powoduje błąd AttributeError,
#       5 # ponieważ self.name nie istnieje w obiekcie mypc.
#
# Cell In[97], line 7, in ElectronicDevice.restart(self)
#       6 def restart(self):
# ----> 7     print(f'Restarting {self.name}')
#
# AttributeError: 'Computer' object has no attribute 'name'

# %% [markdown]
# # 1. KLASA I INSTANCJA:
# # Klasa (np. SmartPhone) to "przepis".
# # Instancja/Obiekt (np. spB) to konkretny telefon stworzony z tego przepisu.
#
# # 2. KONSTRUKTOR __init__:
# # Magiczna metoda, która odpala się SAMA przy tworzeniu obiektu (np. spB = SmartPhone()).
# # Służy do ustawienia startowych danych (atrybutów) obiektu.
# # WAŻNE: Muszą być DWIE podłogi z każdej strony (__), inaczej nie zadziała.
#
# # 3. SŁOWO KLUCZOWE "self":
# # Reprezentuje "ten konkretny" obiekt, na którym właśnie pracujemy.
# # Dzięki self.name = name, Python wie, czyją nazwę ustawia (Boba czy Alice).
#
# # 4. DZIEDZICZENIE:
# # Klasa "dziecko" (np. Computer) przejmuje wszystkie cechy "rodzica" (np. ElectronicDevice).
# # Pozwala to nie pisać tego samego kodu dwa razy.
# Dziedziczenie: Pozwala klasie potomnej (np. Computer) przejąć metody i atrybuty klasy nadrzędnej (np. ElectronicDevice). Zapisuje się to tak: class Computer(ElectronicDevice):
#
# # 5. FUNKCJA super():
# # Używamy jej w "dziecku", żeby wywołać kod z "rodzica" (najczęściej w konstruktorze).
# # Bez super().__init__(name), dziecko "zapomni" ustawić atrybuty od rodzica, co wywali błąd.
#
# # 6. MRO (Method Resolution Order):
# # Kolejka, w której Python szuka metod (najpierw w dziecku, potem w rodzicach, na końcu w 'object').
# NazwaKlasy.__mro__. Python najpierw szuka metody w klasie Computer, a jeśli jej nie znajdzie – idzie wyżej do ElectronicDevice
#
# # 7. METODY SPECJALNE (DUNDER):
# # __str__ -> co wypisać, gdy zrobimy print(obiekt).
# # __len__ -> co zwrócić, gdy zapytamy o len(obiekt).
# # __getitem__ / __setitem__ -> obsługa nawiasów kwadratowych [] jak w słowniku.

# %%
class ElectronicDevice:
    def __init__(self, name = ''):
        print('Creating an Electronic Device')
        self.name = name
        
    def restart(self):
        print(f'Restarting {self.name}')
        
class Computer(ElectronicDevice): # dziedziczenie 
    def __init__(self, name, ram):
        print('Creating a Computer')
        super().__init__(name) # sprawdza jaka klasa jest kolejna w MRO, 
        # czyli pozwala wywoływać konstruktor klasy nadrzędnej
        self.ram = ram

# %%
mypc = Computer('Debesciak PC', 64)
# wywoluje konstruktor klasy potomnej a potem klasy nadrzednej
# Out:
# Creating a Computer
# Creating an Electronic Device

# %%
mypc.restart()
# Out:
# Restarting Debesciak PC

# %%
class ElectronicDevice:
    def __init__(self, name = ''):
        print('Creating an Electronic Device')
        self.name = name
        
    def restart(self):
        print(f'Restarting {self.name}')
        
    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        self.restart()
        
class Computer(ElectronicDevice): # dziedziczenie 
    def __init__(self, name, ram):
        print('Creating a Computer')
        super().__init__(name) # sprawdza jaka klasa jest kolejna w MRO, 
        # czyli pozwala wywoływać konstruktor klasy nadrzędnej
        self.ram = ram
        
    def restart(self): #override nadpisanie metody restart z klasy ElectronicDevice
        print(f'Saving files on computer {self.name}.')

# %%
mypc = Computer('Debesciak PC', 64)
# Out:
# Creating a Computer
# Creating an Electronic Device

# %%
mypc.restart() # wywola metode z klasy Computer
# Out:
# Saving files on computer Debesciak PC.

# %%
mypc.update_firmware()
# Out:
# Updating firmware for Debesciak PC
# Saving files on computer Debesciak PC.

# %%
class ElectronicDevice:
    def __init__(self, name = ''):
        print('Creating an Electronic Device')
        self.name = name
        
    def restart(self):
        print(f'Restarting {self.name}')
        
    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        self.restart()
        
class Computer(ElectronicDevice): # dziedziczenie 
    def __init__(self, name, ram):
        print('Creating a Computer')
        super().__init__(name) # sprawdza jaka klasa jest kolejna w MRO, 
        # czyli pozwala wywoływać konstruktor klasy nadrzędnej
        self.ram = ram
        
    def restart(self): #override nadpisanie metody restart z klasy ElectronicDevice
        print(f'Saving files on computer {self.name}.')
        super().restart() # TU DOPISUJEMY I PATRZYMY JAKA RÓŻNICA

# %%
mypc = Computer('Debesciak 2.0', 67)
# Out:
# Creating a Computer
# Creating an Electronic Device

# %%
mypc.restart()
# Out:
# Saving files on computer Debesciak 2.0.
# Restarting Debesciak 2.0

# %% [markdown]
# super() to sposób, żeby powiedzieć Pythonowi: "Zrób to, co dopisałam tutaj, ALE nie zapomnij też o tym, co było zaprogramowane wcześniej u moich przodków".

# %%
mypc.update_firmware()
# Out:
# Updating firmware for Debesciak 2.0
# Saving files on computer Debesciak 2.0.
# Restarting Debesciak 2.0

# %%
class ElectronicDevice:
    def __init__(self, name = ''):
        print('Creating an Electronic Device')
        self.name = name
        
    def restart(self):
        print(f'Restarting {self.name}')
        
    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        ElectronicDevice.restart(self) # wywołuje metodę restart z klasy ElectronicDevice, a nie z klasy Computer, mimo że mypc jest obiektem klasy Computer, bo używamy nazwy klasy do wywołania metody restart, a nie super().
        
class Computer(ElectronicDevice): # dziedziczenie 
    def __init__(self, name, ram):
        print('Creating a Computer')
        super().__init__(name) # sprawdza jaka klasa jest kolejna w MRO, 
        # czyli pozwala wywoływać konstruktor klasy nadrzędnej
        self.ram = ram
        
    def restart(self): #override nadpisanie metody restart z klasy ElectronicDevice
        print(f'Saving files on computer {self.name}.')
        super().restart() # TU DOPISUJEMY I PATRZYMY JAKA RÓŻNICA

# %%
mypc=Computer('Debesciak PC', 64)
# Out:
# Creating a Computer
# Creating an Electronic Device

# %%
Computer.restart(mypc)
# Out:
# Saving files on computer Debesciak PC.
# Restarting Debesciak PC

# %%
mypc.update_firmware()
# Out:
# Updating firmware for Debesciak PC
# Restarting Debesciak PC

# %%
class ElectronicDevice:
    def __init__(self, name = ''):
        print('Creating an Electronic Device')
        self.name = name
        
    def restart(self):
        print(f'Restarting {self.name}')


    __restart=restart #przypisujemy funckje do nowej zmiennej 
    # __ to specjalna składnia jesli wewnatrz klasy robimy __ dołacza nazwę tej klasy czyli z tej klasy, czyli robimy kopię metody a nie override i odwołujemy się do kopii metody a nie samej metody
    # _ to jest przypomnienie zeby nie zmieniac tej zmiennej
        
    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        self.__restart() 
class Computer(ElectronicDevice): # dziedziczenie 
    def __init__(self, name, ram):
        print('Creating a Computer')
        super().__init__(name) # sprawdza jaka klasa jest kolejna w MRO, 
        # czyli pozwala wywoływać konstruktor klasy nadrzędnej
        self.ram = ram
        
    def restart(self): #override nadpisanie metody restart z klasy ElectronicDevice
        print(f'Saving files on computer {self.name}.')
        super().restart() # TU DOPISUJEMY I PATRZYMY JAKA RÓŻNICA

# %%
mypc=Computer('Debesciak PC', 64)
# Out:
# Creating a Computer
# Creating an Electronic Device

# %%
mypc.update_firmware()
# Out:
# Updating firmware for Debesciak PC
# Restarting Debesciak PC

# %%
mypc.__restart()
#nie zadziałało ponieważ
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 mypc.__restart()
#       2 #nie zadziałało ponieważ
#
# AttributeError: 'Computer' object has no attribute '__restart'

# %% [markdown]
# WIELOKROTNE DZIEDZICZENIE

# %%
class ElectronicDevice:
    def __init__(self, name = ''):
        print('Creating an Electronic Device')
        self.name = name
        
    def restart(self):
        print(f'Restarting {self.name}')


    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        ElectronicDevice.restart(self)

class Computer(ElectronicDevice): # dziedziczenie 
    def __init__(self, name, ram):
        print('Creating a Computer')
        super().__init__(name) # sprawdza jaka klasa jest kolejna w MRO, 
        # czyli pozwala wywoływać konstruktor klasy nadrzędnej
        self.ram = ram
        
    def restart(self): #override nadpisanie metody restart z klasy ElectronicDevice
        print(f'Saving files on computer {self.name}.')
        super().restart() # TU DOPISUJEMY I PATRZYMY JAKA RÓŻNICA

class Camera(ElectronicDevice):
    def __init__(self,name,width,height):
        print('Creating a Camera')
        super().__init__(name) #wywyołuje konstruktor klasy bazowej który ma tylko name
        self.width = width #zapsiywanie do atrybutów
        self.height = height


    def restart(self):
        print(f'Backing up photos on {self.name}')
        super().restart()

# %%
mycamera=Camera("Bob's camera", 1024, 768)
mycamera.restart()
# Out:
# Creating a Camera
# Creating an Electronic Device
# Backing up photos on Bob's camera
# Restarting Bob's camera

# %%
class ElectronicDevice:
    def __init__(self, name = ''):
        print('Creating an Electronic Device')
        self.name = name
        
    def restart(self):
        print(f'Restarting {self.name}')


    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        self.restart()

class Computer(ElectronicDevice): # dziedziczenie 
    def __init__(self, ram,**kwargs):
        print(f'Creating a Computer {kwargs=}')
        super().__init__(**kwargs) # sprawdza jaka klasa jest kolejna w MRO
        self.ram = ram
        
    def restart(self): #override nadpisanie metody restart z klasy ElectronicDevice
        print(f'Saving files on computer {self.name}.')
        super().restart() # TU DOPISUJEMY I PATRZYMY JAKA RÓŻNICA

class Camera(ElectronicDevice):
    def __init__(self,width,height,**kwargs):
        print(f'Creating a Camera {kwargs=}')
        super().__init__(**kwargs) #wywyołuje konstruktor klasy bazowej który ma tylko name
        self.width = width #zapsiywanie do atrybutów
        self.height = height


    def restart(self):
        print(f'Backing up photos on {self.name}')
        super().restart()

class SmartPhone(Computer,Camera):
    def __init__(self,name,ram,width,height):
        print('Creating a SmartPhone')
        #tego raczej nie robić 
        #Computer.__init__(self,name,ram) 
        #Camera.__init__(self,name,width,height) 
        args = {'name': name, 'ram': ram, 'width': width, 'height': height} #robie słownik z argumentami i zamieniamy na klucze
        super().__init__(**args) #

# %%
SmartPhone.__mro__
# Out:
# (__main__.SmartPhone,
#  __main__.Computer,
#  __main__.Camera,
#  __main__.ElectronicDevice,
#  object)

# %%
phone=SmartPhone("Bob's phone", 64, 1024, 768)
# Out:
# Creating a SmartPhone
# Creating a Computer kwargs={'name': "Bob's phone", 'width': 1024, 'height': 768}
# Creating a Camera kwargs={'name': "Bob's phone"}
# Creating an Electronic Device

# %%
camera= Camera(1024, 768, name="Bob's camera")
# Out:
# Creating a Camera kwargs={'name': "Bob's camera"}
# Creating an Electronic Device

# %%
from abc import ABC, abstractmethod


class ElectronicDevice(ABC):
    def __init__(self, name = '',**kwargs):
        print('Creating an Electronic Device')
        self.name = name
    @abstractmethod #tak sie dekoruje 
#dekoratory w pythonie to funkcje, które modyfikują inne funkcje, np. @abstractmethod oznacza, że metoda jest abstrakcyjna i musi być zaimplementowana w klasach dziedziczących, a nie może być wywoływana bezpośrednio na obiekcie klasy bazowej.
    def restart(self):
        print(f'Restarting {self.name}')


    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        self.restart()

class Computer(ElectronicDevice): # dziedziczenie 
    def __init__(self, ram,**kwargs):
        print(f'Creating a Computer {kwargs=}')
        super().__init__(**kwargs) # sprawdza jaka klasa jest kolejna w MRO
        self.ram = ram
        
    def restart(self): #override nadpisanie metody restart z klasy ElectronicDevice
        print(f'Saving files on computer {self.name}.')
        super().restart() # TU DOPISUJEMY I PATRZYMY JAKA RÓŻNICA

class Camera(ElectronicDevice):
    def __init__(self,width,height,**kwargs):
        print(f'Creating a Camera {kwargs=}')
        super().__init__(**kwargs) #wywyołuje konstruktor klasy bazowej który ma tylko name
        self.width = width #zapsiywanie do atrybutów
        self.height = height


    def restart(self):
        print(f'Backing up photos on {self.name}')
        super().restart()

class SmartPhone(Computer,Camera):
    def __init__(self,name,ram,width,height):
        print('Creating a SmartPhone')
        #tego raczej nie robić 
        #Computer.__init__(self,name,ram) 
        #Camera.__init__(self,name,width,height) 
        args = {'name': name, 'ram': ram, 'width': width, 'height': height} #robie słownik z argumentami i zamieniamy na klucze
        super().__init__(**args) #

# %%
ed=ElectronicDevice('Some device') #muszą byc przeciązone w klasie potomnej, bo metoda restart jest abstrakcyjna i musi być zaimplementowana w klasach dziedziczących, a nie może być wywoływana bezpośrednio na obiekcie klasy bazowej.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 ed=ElectronicDevice('Some device')
#
# TypeError: Can't instantiate abstract class ElectronicDevice without an implementation for abstract method 'restart'

# %% [markdown]
# ---

# %% [markdown]
# jak działają **
# ### dygresja - funkcje z nieskończoną liczbą argumentów

# %%
def some_function(x,y=1): #x arg pozycyjny, y arg domyślny
    return x+y

# %%
some_function(1,2)
# Out:
# 3

# %%
some_function(5)
# Out:
# 6

# %%
args=[1,2]
some_function(args[0], args[1])
# Out:
# 3

# %%
some_function(*args)#rozpakowuje listę jeden po drugim jak powyżej
# Out:
# 3

# %%
args={'x': 1, 'y': 2} #kllucz x któemu jest przypisana wartość 1 i klucz y któremu jest przypisana wartość 2
some_function(**args) #rozpakowuje słownik, po słownikowych i nazwa pozycyhna musi byc taka sama jak słownika
# Out:
# 3

# %%
kwargs={'y':2}

# %%
def some_function(x,y, *args,z=4, **kwargs):
    print(f'x={x}, y={y}, args={args}, z={z}, kwargs={kwargs}')

# %%
some_function(1,2,3,4,5)
# Out:
# x=1, y=2, args=(3, 4, 5), z=4, kwargs={}

# %%
some_function(1,2,3,4,5,xd=7,lol=8,rotfl=90)
# Out:
# x=1, y=2, args=(3, 4, 5), z=4, kwargs={'xd': 7, 'lol': 8, 'rotfl': 90}

# %% [markdown]
# ---

# %%
class SmartPhone:
    name = ''
    address_book = {}
    
    def __init__(self):
        print('Creating a SmartPhone')

# %%
sp = SmartPhone()
sp.name = "Bob's Phone"
sp.address_book['Alice'] = '123-456-7890'
sp.address_book['Charlie'] = '987-654-3210'
# Out:
# Creating a SmartPhone

# %%
sp.name, sp.address_book
# Out:
# ("Bob's Phone", {'Alice': '123-456-7890', 'Charlie': '987-654-3210'})

# %%
spB = SmartPhone()
spB.name = "Bob's Phone"
spB.address_book['Alice'] = '123-456-7890'
spB.address_book['Charlie'] = '987-654-3210'

spA = SmartPhone()
spA.name = "Alice's Phone"
spA.address_book['Bob'] = '123-456-0000'
spA.address_book['Charlie'] = '987-654-3210'
# Out:
# Creating a SmartPhone
# Creating a SmartPhone

# %%
spB.name, spB.address_book
# Out:
# ("Bob's Phone",
#  {'Alice': '123-456-7890', 'Charlie': '987-654-3210', 'Bob': '123-456-0000'})

# %%
spA.name, spA.address_book
# Out:
# ("Alice's Phone",
#  {'Alice': '123-456-7890', 'Charlie': '987-654-3210', 'Bob': '123-456-0000'})

# %%
class SmartPhone:
    def __init__(self, name = ''):
        print('Creating a SmartPhone')
        self.name = name
        self.address_book = {}

# %%
spB = SmartPhone("Bob's Phone")
spB.address_book['Alice'] = '123-456-7890'
spB.address_book['Charlie'] = '987-654-3210'

spA = SmartPhone("Alice's Phone")
spA.address_book['Bob'] = '123-456-0000'
spA.address_book['Charlie'] = '987-654-3210'
# Out:
# Creating a SmartPhone
# Creating a SmartPhone

# %%
spB.name, spB.address_book
# Out:
# ("Bob's Phone", {'Alice': '123-456-7890', 'Charlie': '987-654-3210'})

# %%
spA.name, spA.address_book
# Out:
# ("Alice's Phone", {'Bob': '123-456-0000', 'Charlie': '987-654-3210'})

# %%
spA.hakuna_matata = 'It means no worries'
spA.hakuna_matata
# Out:
# 'It means no worries'

# %%
class SmartPhone:
    def __init__(self, name = ''):
        print('Creating a SmartPhone')
        self.name = name
        self.address_book = {}
    
    def restart(self):
        print(f'Restarting {self.name}')

# %%
spB = SmartPhone("Bob's Phone")
spB.address_book['Alice'] = '123-456-7890'
spB.address_book['Charlie'] = '987-654-3210'
# Out:
# Creating a SmartPhone

# %%
spB.restart()
# Out:
# Restarting Bob's Phone

# %%
import random

class SmartPhone:
    def __init__(self, name = ''):
        print('Creating a SmartPhone')
        self.name = name
        self.address_book = {}
        self._secret_code = random.randint(1000, 9999)
    
    def restart(self):
        print(f'Restarting {self.name}')

    def send_data_to_china(self):
        print(f'Sending data to China with secret code {self._secret_code}')

# %%
spB = SmartPhone("Bob's Phone")
spB.address_book['Alice'] = '123-456-7890'
spB.address_book['Charlie'] = '987-654-3210'
# Out:
# Creating a SmartPhone

# %%
spB.send_data_to_china()
# Out:
# Sending data to China with secret code 5493

# %%
spB._secret_code = 'FU'

# %%
spB.send_data_to_china()
# Out:
# Sending data to China with secret code FU

# %%
import random

class SmartPhone:
    def __init__(self, name = ''):
        print('Creating a SmartPhone')
        self.name = name
        self.address_book = {}
        self._secret_code = random.randint(1000, 9999)
    
    def restart(self):
        print(f'Restarting {self.name}')

    def send_data_to_china(self):
        print(f'Sending data to China with secret code {self._secret_code}')

    def __str__(self):
        return f'SmartPhone(name={self.name}, address_book={self.address_book})'
    
    def __getitem__(self, key):
        return self.address_book[key]

    def __setitem__(self, key, value):
        self.address_book[key] = value

    def __len__(self):
        return len(self.address_book)

# %%
spB = SmartPhone("Bob's Phone")
spB.address_book['Alice'] = '123-456-7890'
spB.address_book['Charlie'] = '987-654-3210'
# Out:
# Creating a SmartPhone

# %%
print(spB)
# Out:
# SmartPhone(name=Bob's Phone, address_book={'Alice': '123-456-7890', 'Charlie': '987-654-3210'})

# %%
spB['Alice']
# Out:
# '123-456-7890'

# %%
spB['Alice'] = '555-555-5555'

# %%
spB['Alice']
# Out:
# '555-555-5555'

# %%
len(spB)
# Out:
# 2

# %% [markdown]
# # Dziedziczenie

# %%
class ElectronicDevice:
    def __init__(self, name = ''):
        print('Creating an Electronic Device')
        self.name = name
    
    def restart(self):
        print(f'Restarting {self.name}')

class Computer(ElectronicDevice):
    pass

# %%
mypc = Computer('My PC')
# Out:
# Creating an Electronic Device

# %%
mypc.restart()
# Out:
# Restarting My PC

# %% [markdown]
# # MRO

# %%
Computer.__mro__
# Out:
# (__main__.Computer, __main__.ElectronicDevice, object)

# %%
class ElectronicDevice:
    def __init__(self, name = ''):
        print('Creating an Electronic Device')
        self.name = name
    
    def restart(self):
        print(f'Restarting {self.name}')

class Computer(ElectronicDevice):
    def __init__(self, ram):
        print('Creating a Computer')
        self.ram = ram

# %%
mypc = Computer(64)
# Out:
# Creating a Computer

# %%
mypc.ram
# Out:
# 64

# %%
mypc.restart()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 mypc.restart()
#
# Cell In[43], line 7, in ElectronicDevice.restart(self)
#       6 def restart(self):
# ----> 7     print(f'Restarting {self.name}')
#
# AttributeError: 'Computer' object has no attribute 'name'

# %%
class ElectronicDevice:
    def __init__(self, name = ''):
        print('Creating an Electronic Device')
        self.name = name
    
    def restart(self):
        print(f'Restarting {self.name}')

class Computer(ElectronicDevice):
    def __init__(self, name, ram):
        print('Creating a Computer')
        super().__init__(name)
        self.ram = ram

# %%
mypc = Computer('Debesciak PC', 64)
# Out:
# Creating a Computer
# Creating an Electronic Device

# %%
mypc.restart()
# Out:
# Restarting Debesciak PC

# %%
class ElectronicDevice:
    def __init__(self, name = ''):
        print('Creating an Electronic Device')
        self.name = name
    
    def restart(self):
        print(f'Restarting {self.name}')
    
    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        self.restart()

class Computer(ElectronicDevice):
    def __init__(self, name, ram):
        print('Creating a Computer')
        super().__init__(name)
        self.ram = ram

    def restart(self):
        print(f'Saving files on computer {self.name}.')

# %%
mypc = Computer('Debesciak PC', 64)
# Out:
# Creating a Computer
# Creating an Electronic Device

# %%
mypc.restart()
# Out:
# Saving files on computer Debesciak PC.

# %%
mypc.update_firmware()
# Out:
# Updating firmware for Debesciak PC
# Saving files on computer Debesciak PC.

# %%
class ElectronicDevice:
    def __init__(self, name=''):
        print('Creating an Electronic Device')
        self.name = name
    
    def restart(self):
        print(f'Restarting {self.name}')
    
    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        self.restart()

class Computer(ElectronicDevice):
    def __init__(self, name, ram):
        print('Creating a Computer')
        super().__init__(name)
        self.ram = ram

    def restart(self):
        print(f'Saving files on computer {self.name}.')
        super().restart()

# %%
mypc = Computer('Debesciak PC', 64)
# Out:
# Creating a Computer
# Creating an Electronic Device

# %%
mypc.restart()
# Out:
# Saving files on computer Debesciak PC.
# Restarting Debesciak PC

# %%
mypc.update_firmware()
# Out:
# Updating firmware for Debesciak PC
# Saving files on computer Debesciak PC.
# Restarting Debesciak PC

# %%
class ElectronicDevice:
    def __init__(self, name=''):
        print('Creating an Electronic Device')
        self.name = name
    
    def restart(self):
        print(f'Restarting {self.name}')
    
    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        ElectronicDevice.restart(self)

class Computer(ElectronicDevice):
    def __init__(self, name, ram):
        print('Creating a Computer')
        super().__init__(name)
        self.ram = ram

    def restart(self):
        print(f'Saving files on computer {self.name}.')
        super().restart()

# %%
mypc = Computer('Debesciak PC', 64)
# Out:
# Creating a Computer
# Creating an Electronic Device

# %%
mypc.restart()
# Out:
# Saving files on computer Debesciak PC.
# Restarting Debesciak PC

# %%
#Computer.restart(mypc)
# Out:
# Saving files on computer Debesciak PC.
# Restarting Debesciak PC

# %%
mypc.update_firmware()
# Out:
# Updating firmware for Debesciak PC
# Restarting Debesciak PC

# %%
class ElectronicDevice:
    def __init__(self, name=''):
        print('Creating an Electronic Device')
        self.name = name
    
    def restart(self):
        print(f'Restarting {self.name}')
    
    __restart = restart

    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        self.__restart()

class Computer(ElectronicDevice):
    def __init__(self, name, ram):
        print('Creating a Computer')
        super().__init__(name)
        self.ram = ram

    def restart(self):
        print(f'Saving files on computer {self.name}.')
        super().restart()

# %%
mypc = Computer('Debesciak PC', 64)
# Out:
# Creating a Computer
# Creating an Electronic Device

# %%
mypc.update_firmware()
# Out:
# Updating firmware for Debesciak PC
# Restarting Debesciak PC

# %%
mypc._restart()
# Out:
# Restarting Debesciak PC

# %%
class ElectronicDevice:
    def __init__(self, name=''):
        print('Creating an Electronic Device')
        self.name = name
    
    def restart(self):
        print(f'Restarting {self.name}')
    
    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        ElectronicDevice.restart(self)

class Computer(ElectronicDevice):
    def __init__(self, name, ram):
        print('Creating a Computer')
        super().__init__(name)
        self.ram = ram

    def restart(self):
        print(f'Saving files on computer {self.name}.')
        super().restart()

# %%
class ElectronicDevice:
    def __init__(self, name=''):
        print('Creating an Electronic Device')
        self.name = name
    
    def restart(self):
        print(f'Restarting {self.name}')
    
    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        ElectronicDevice.restart(self)

class Computer(ElectronicDevice):
    def __init__(self, name, ram):
        print('Creating a Computer')
        super().__init__(name)
        self.ram = ram

    def restart(self):
        print(f'Saving files on computer {self.name}.')
        super().restart()

class Camera(ElectronicDevice):
    def __init__(self, name, width, height):
        print('Creating a Camera')
        super().__init__(name)
        self.width = width
        self.height = height

    def restart(self):
        print(f'Backing up photos on {self.name}')
        super().restart()

# %%
mycamera = Camera("Bob's camera", 1024, 768)
mycamera.restart()
# Out:
# Creating a Camera
# Creating an Electronic Device
# Backing up photos on Bob's camera
# Restarting Bob's camera

# %%
class ElectronicDevice:
    def __init__(self, name=''):
        print('Creating an Electronic Device')
        self.name = name
    
    def restart(self):
        print(f'Restarting {self.name}')
    
    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        self.restart()

class Computer(ElectronicDevice):
    def __init__(self, name, ram):
        print('Creating a Computer')
        super().__init__(name)
        self.ram = ram

    def restart(self):
        print(f'Saving files on computer {self.name}.')
        super().restart()

class Camera(ElectronicDevice):
    def __init__(self, name, width, height):
        print('Creating a Camera')
        super().__init__(name)
        self.width = width
        self.height = height

    def restart(self):
        print(f'Backing up photos on {self.name}')
        super().restart()

class SmartPhone(Computer, Camera):
    def __init__(self, name, ram, width, height):
        print('Creating a SmartPhone')
        Computer.__init__(self, name, ram)
        Camera.__init__(self, name, width, height)

# %%
phone = SmartPhone("Bob's Phone", 64, 1024, 768)
# Out:
# Creating a SmartPhone
# Creating a Computer
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 phone = SmartPhone("Bob's Phone", 64, 1024, 768)
#
# Cell In[24], line 37, in SmartPhone.__init__(self, name, ram, width, height)
#      35 def __init__(self, name, ram, width, height):
#      36     print('Creating a SmartPhone')
# ---> 37     Computer.__init__(self, name, ram)
#      38     Camera.__init__(self, name, width, height)
#
# Cell In[24], line 16, in Computer.__init__(self, name, ram)
#      14 def __init__(self, name, ram):
#      15     print('Creating a Computer')
# ---> 16     super().__init__(name)
#      17     self.ram = ram
#
# TypeError: Camera.__init__() missing 2 required positional arguments: 'width' and 'height'

# %%
SmartPhone.__mro__
# Out:
# (__main__.SmartPhone,
#  __main__.Computer,
#  __main__.Camera,
#  __main__.ElectronicDevice,
#  object)

# %%
class ElectronicDevice:
    def __init__(self, name=''):
        print('Creating an Electronic Device')
        self.name = name
    
    def restart(self):
        print(f'Restarting {self.name}')
    
    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        self.restart()

class Computer(ElectronicDevice):
    def __init__(self, name, ram):
        print('Creating a Computer')
        ElectronicDevice.__init__(self, name)
        self.ram = ram

    def restart(self):
        print(f'Saving files on computer {self.name}.')
        super().restart()

class Camera(ElectronicDevice):
    def __init__(self, name, width, height):
        print('Creating a Camera')
        ElectronicDevice.__init__(self, name)
        self.width = width
        self.height = height

    def restart(self):
        print(f'Backing up photos on {self.name}')
        super().restart()

class SmartPhone(Computer, Camera):
    def __init__(self, name, ram, width, height):
        print('Creating a SmartPhone')
        Computer.__init__(self, name, ram)
        Camera.__init__(self, name, width, height)

# %%
phone = SmartPhone("Bob's Phone", 64, 1024, 768)
# Out:
# Creating a SmartPhone
# Creating a Computer
# Creating an Electronic Device
# Creating a Camera
# Creating an Electronic Device

# %%
class ElectronicDevice:
    def __init__(self, name='', **kwargs):
        print(f'Creating an Electronic Device {kwargs=}')
        self.name = name
    
    def restart(self):
        print(f'Restarting {self.name}')
    
    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        self.restart()

class Computer(ElectronicDevice):
    def __init__(self, ram, **kwargs):
        print(f'Creating a Computer {kwargs=}')
        super().__init__(**kwargs)
        self.ram = ram

    def restart(self):
        print(f'Saving files on computer {self.name}.')
        super().restart()

class Camera(ElectronicDevice):
    def __init__(self, width, height, **kwargs):
        print(f'Creating a Camera {kwargs=}')
        super().__init__(**kwargs)
        self.width = width
        self.height = height

    def restart(self):
        print(f'Backing up photos on {self.name}')
        super().restart()

class SmartPhone(Camera, Computer):
    def __init__(self, name, ram, width, height):
        print('Creating a SmartPhone')
        args = {'name': name, 'ram': ram, 'width': width, 'height': height}
        super().__init__(**args)

# %%
phone = SmartPhone("Bob's Phone", 64, 1024, 768)
# Out:
# Creating a SmartPhone
# Creating a Camera kwargs={'name': "Bob's Phone", 'ram': 64}
# Creating a Computer kwargs={'name': "Bob's Phone"}
# Creating an Electronic Device kwargs={}

# %%
camera = Camera(1024, 768, name='Bob camera')
# Out:
# Creating a Camera kwargs={'name': 'Bob camera'}
# Creating an Electronic Device kwargs={}

# %%
SmartPhone.__mro__
# Out:
# (__main__.SmartPhone,
#  __main__.Computer,
#  __main__.Camera,
#  __main__.ElectronicDevice,
#  object)

# %% [markdown]
# ### Szybka dygresja - funkcje z nieskończoną liczbą argumentów

# %%
def some_function(x, y=1):
    return x + y

# %%
some_function(1, 2)
# Out:
# 3

# %%
some_function(1)
# Out:
# 2

# %%
some_function(1, y=2)
# Out:
# 3

# %%
some_function(x=1, y=2)
# Out:
# 3

# %%
args = [1, 2]

# %%
some_function(args[0], args[1])
# Out:
# 3

# %%
some_function(*args)
# Out:
# 3

# %%
args = {'x': 1, 'y': 2}

# %%
some_function(**args)
# Out:
# 3

# %%
args = [1]
kwargs = {'y': 2}

some_function(*args, **kwargs)
# Out:
# 3

# %%
def some_function(x, y, *args, z=4, **kwargs):
    print(f'x={x}, y={y}, args={args}, z={z}, kwargs={kwargs}')

# %%
some_function(1, 2, 3, 4, 5, z=6, xd=7, lol=8, rotfl=90)
# Out:
# x=1, y=2, args=(3, 4, 5), z=6, kwargs={'xd': 7, 'lol': 8, 'rotfl': 90}

# %% [markdown]
# ---

# %%
from abc import ABC, abstractmethod

class ElectronicDevice(ABC):
    def __init__(self, name='', **kwargs):
        print(f'Creating an Electronic Device {kwargs=}')
        self.name = name
    
    @abstractmethod
    def restart(self):
        print(f'Restarting {self.name}')
    
    def update_firmware(self):
        print(f'Updating firmware for {self.name}')
        self.restart()

class Computer(ElectronicDevice):
    def __init__(self, ram, **kwargs):
        print(f'Creating a Computer {kwargs=}')
        super().__init__(**kwargs)
        self.ram = ram

    def restart(self):
        print(f'Saving files on computer {self.name}.')
        super().restart()

class Camera(ElectronicDevice):
    def __init__(self, width, height, **kwargs):
        print(f'Creating a Camera {kwargs=}')
        super().__init__(**kwargs)
        self.width = width
        self.height = height

    def restart(self):
        print(f'Backing up photos on {self.name}')
        super().restart()

class SmartPhone(Camera, Computer):
    def __init__(self, name, ram, width, height):
        print('Creating a SmartPhone')
        args = {'name': name, 'ram': ram, 'width': width, 'height': height}
        super().__init__(**args)

# %%
ed = ElectronicDevice('Some device')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 ed = ElectronicDevice('Some device')
#
# TypeError: Can't instantiate abstract class ElectronicDevice without an implementation for abstract method 'restart'

# %%
computer = Computer(64, name='My PC')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 computer = Computer(64, name='My PC')
#
# TypeError: Can't instantiate abstract class Computer without an implementation for abstract method 'restart'
